# %%
import pandas as pd

from GoogleNews import GoogleNews
from newspaper import Article
import pandas as pd
from newspaper import Article
from newspaper import Config
import nltk

# %%
list=[]

googlenews=GoogleNews(start='02/10/2021',end='06/20/2021')
googlenews.search("Jackson Misissippi water crisis")
result=googlenews.result()
df=pd.DataFrame(result)

for i in range(2,25):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 50


for ind in df.index:
    try:
        dict={}
        article = Article(df['link'][ind],config=config)
        article.download()
        article.parse()
        article.nlp()
        dict['Date']=df['date'][ind]
        dict['Media']=df['media'][ind]
        dict['Title']=article.title
        dict['Article']=article.text
        dict['Summary']=article.summary
        list.append(dict)
    except:
        print("caught a timeout")

googlenews.clear()

news_df_JWC=pd.DataFrame(list)
news_df_JWC
# Out:
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# 'NoneType' object is not iterable
# caught a timeout
# caught a timeout
#                   Date               Media  \
# 0          Mar 2, 2021            NBC News
# 1          Mar 2, 2021                 CNN
# 2          Mar 3, 2021           USA Today
# 3         Mar 15, 2021               Slate
# 4    th · Mar 22, 2021  The New York Times
# ..                 ...                 ...
# 171        1 month ago                WAPT
# 172       Apr 14, 2021  The Clarion-Ledger
# 173       Apr 14, 2021                WJTV
# 174        Apr 5, 2021  The New York Times
# 175       Apr 16, 2021            WGNO.com
#
#                                                  Title  \
# 0    Jackson, Mississippi, water crisis brings to l...
# 1    In Jackson, Mississippi, some residents have b...
# ...

# %%
news_df_JWC.to_csv("newsData/google_JMWaterCrisis.csv")

# %%
keywords=['Jackson Mississippi water crisis', 'Jackson Mississippi water outage']
list=[]
for keyword in keywords:
    googlenews=GoogleNews(start='02/10/2021',end='06/20/2021')
    googlenews.search(keyword)
    result=googlenews.result()
    df=pd.DataFrame(result)

    for i in range(2,15):
        googlenews.getpage(i)
        result=googlenews.result()
        df=pd.DataFrame(result)
        
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
    config = Config()
    config.browser_user_agent = user_agent
    config.request_timeout = 50

    
    for ind in df.index:
        try:
            dict={}
            article = Article(df['link'][ind],config=config)
            article.download()
            article.parse()
            article.nlp()
            dict['Date']=df['date'][ind]
            dict['Media']=df['media'][ind]
            dict['Title']=article.title
            dict['Article']=article.text
            dict['Summary']=article.summary
            dict['Keyword']=keyword
            list.append(dict)
        except:
            print("caught a timeout")
    
    googlenews.clear()
    
news_df_JWC=pd.DataFrame(list)
news_df_JWC
# Out:
# caught a timeout
# caught a timeout
# caught a timeout
# C:\Users\rishabhstha\AppData\Local\Programs\Python\Python38\lib\site-packages\dateutil\parser\_parser.py:1213: UnknownTimezoneWarning: tzname CST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
#                   Date               Media  \
# 0          Mar 2, 2021            NBC News
# 1          Mar 2, 2021                 CNN
# 2          Mar 3, 2021           USA Today
# 3         Mar 15, 2021               Slate
# 4    th · Mar 22, 2021  The New York Times
# ..                 ...                 ...
# 272       Mar 19, 2021                WJTV
# 273       Feb 11, 2021               Kait8
# 274        Mar 1, 2021                WAPT
# 275       Apr 24, 2021                WJTV
# 276        Mar 4, 2021                WLBT
#
# ...

# %%
news_df_JWC=news_df_JWC.drop_duplicates(subset='Title')
news_df_JWC.to_csv("newsData/google_JWCallnews.csv")

# %%
#keyword- Nick Judin JWC
list=[]

googlenews=GoogleNews(start='02/10/2021',end='06/20/2021')
googlenews.search("Nick Judin Jackson water crisis")
result=googlenews.result()
df=pd.DataFrame(result)

for i in range(2,3):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 50


for ind in df.index:
    try:
        dict={}
        article = Article(df['link'][ind],config=config)
        article.download()
        article.parse()
        article.nlp()
        dict['Date']=df['date'][ind]
        dict['Media']=df['media'][ind]
        dict['Title']=article.title
        dict['Article']=article.text
        dict['Summary']=article.summary
        list.append(dict)
    except:
        print("caught a timeout")

googlenews.clear()

news_df_NickJWC=pd.DataFrame(list)
news_df_NickJWC
# Out:
# 'NoneType' object is not iterable
#            Date                   Media  \
# 0   Mar 3, 2021      Jackson Free Press
# 1  Mar 23, 2021                   Slate
# 2  Mar 23, 2021          Slate Magazine
# 3   Mar 6, 2021                NBC News
# 4  Mar 26, 2021                    WBUR
# 5  Mar 25, 2021  Mississippi Free Press
# 6   1 month ago  Mississippi Free Press
# 7   1 month ago  Mississippi Free Press
#
#                                                Title  \
# 0  PUBLISHER'S NOTE: Jackson’s Water Crisis, What...
# 1  The Next Major Water Crisis Is Right Around th...
# 2                            One Month Without Water
# 3  Jackson, Mississippi has a water crisis becaus...
# 4  The Jackson, Mississippi Water Crisis And Amer...
# 5         Pandemic Timeline: COVID-19 in Mississippi
# 6  Department of Justice Reveals Plan For Ailing ...
# 7  ‘Breaking Point’: Restaurant Workers Push Back...
#
#                                              Article  \
# ...

# %%
news_df_NickJWC['Title'].to_list()
# Out:
# ["PUBLISHER'S NOTE: Jackson’s Water Crisis, What Would Ditto Do?",
#  'The Next Major Water Crisis Is Right Around the Corner',
#  'One Month Without Water',
#  'Jackson, Mississippi has a water crisis because our state legislature has a race problem',
#  "The Jackson, Mississippi Water Crisis And America's Crumbling Water System",
#  'Department of Justice Reveals Plan For Ailing Mississippi Department of Mental Health',
#  'Pandemic Timeline: COVID-19 in Mississippi',
#  '‘Breaking Point’: Restaurant Workers Push Back Amid Unemployment Benefit Crackdown']

# %%
#keyword- Nick Judin JWC
list=[]

googlenews=GoogleNews(start='02/10/2021',end='06/20/2021')
googlenews.search("Nick Judin Jackson water crisis")
result=googlenews.result()
df=pd.DataFrame(result)

for i in range(2,3):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 50


for ind in df.index:
    try:
        dict={}
        article = Article(df['link'][ind],config=config)
        article.download()
        article.parse()
        article.nlp()
        dict['Date']=df['date'][ind]
        dict['Media']=df['media'][ind]
        dict['Title']=article.title
        dict['Article']=article.text
        dict['Summary']=article.summary
        list.append(dict)
    except:
        print("caught a timeout")

googlenews.clear()


urls=["https://www.mississippifreepress.org/9824/lt-gov-hosemann-blames-jackson-leadership-since-last-white-mayor-for-water-crisis-mayor-harvey-johnson-jr-fires-back/",
     "https://www.mississippifreepress.org/10682/under-the-surface-part-2-after-jackson-freeze-the-fog-of-war/"]
for url in urls:
    try:
        dict={}
        print(url)
        article = Article(url,config=config)
        article.download()
        article.parse()
        article.nlp()
    
        dict['Date']=article.publish_date
        dict['Title']=article.title
        dict['Article']=article.text
        dict['Summary']=article.summary
        list.append(dict)
    except:
        print("caught a timeout")

news_df_NickJWC=pd.DataFrame(list)
news_df_NickJWC
# Out:
# 'NoneType' object is not iterable
# https://www.mississippifreepress.org/9824/lt-gov-hosemann-blames-jackson-leadership-since-last-white-mayor-for-water-crisis-mayor-harvey-johnson-jr-fires-back/
# https://www.mississippifreepress.org/10682/under-the-surface-part-2-after-jackson-freeze-the-fog-of-war/
#                         Date                   Media  \
# 0                Mar 3, 2021      Jackson Free Press
# 1               Mar 23, 2021                   Slate
# 2               Mar 23, 2021          Slate Magazine
# 3                Mar 6, 2021                NBC News
# 4               Mar 26, 2021                    WBUR
# 5                1 month ago  Mississippi Free Press
# 6               Mar 25, 2021  Mississippi Free Press
# 7                1 month ago  Mississippi Free Press
# 8  2021-03-02 01:54:57+00:00                     NaN
# https://www.npr.org/2021/03/03/973175017/like-peanut-brittle-mississippi-water-crisis-highlights-infrastructure-problems
# https://www.usatoday.com/story/news/nation/2021/03/09/jackson-mississippi-water-crisis-how-started-and-what-know/4641990001/
# https://www.usatoday.com/story/news/nation/2021/03/03/jackson-mississippi-water-crisis-city-unsure-how-many-affected/6902171002/
# https://mississippitoday.org/2021/03/24/why-jacksons-water-system-is-broken/
# https://www.nbcnews.com/news/us-news/jackson-mississippi-water-crisis-brings-light-long-standing-problems-city-n1259376
# ...

# %%
#Using datanews io API-- can't have full article
import datanews
import pandas as pd

datanews.api_key = '0e1oixqnn4f0fhdl3zod701ok'

response = datanews.news(q='Jackson++Mississippi+water+crisis', from_date=("2021-02-10"),country='US',language=['en'],size=100)

articles = response['hits']

titles=[]
dates=[]
for article in articles:
    titles.append(article['title'])
    dates.append(article['pubDate'])



df_curl=pd.DataFrame.from_dict(response)

df_curl.hits


list_result=[]
for i in range(len(df_curl.hits)):
    new_dict={}
    new_dict['url']=df_curl.hits[i]['url']
    new_dict['source']=df_curl.hits[i]['source']
    new_dict['authors']=df_curl.hits[i]['authors']
    new_dict['title']=df_curl.hits[i]['title']
    new_dict['pubDate']=df_curl.hits[i]['pubDate']
    new_dict['country']=df_curl.hits[i]['country']
    new_dict['language']=df_curl.hits[i]['language']
    new_dict['description']=df_curl.hits[i]['description']
    new_dict['imageUrl']=df_curl.hits[i]['imageUrl']
    new_dict['content']=df_curl.hits[i]['content']


    list_result.append(new_dict)



df_datanews=pd.DataFrame.from_dict(list_result)

df_datanews=df_datanews.drop_duplicates(subset='title')

# %%
df_datanews
df_datanews.to_csv("newsData/datanewsio_JWCallnews.csv")

# %%
df_datanews['title'].to_list()
# Out:
# ['"60 Minutes+" examines the effects of the water crisis on Jackson, Mississippi residents',
#  'Jackson, Mississippi has an ongoing water crisis. Here’s how it’s impacting citizens.',
#  'Jackson, Mississippi has an ongoing water crisis. Here’s how it’s impacting its citizens.',
#  "The History Of Jackson, Mississippi's Water Crisis | Here & Now",
#  'Thousands go without water in Mississippi amid crisis: State Rep. Ronnie Crudup',
#  'Jackson Mississippi: Two Weeks Without Running Water',
#  '"60 Minutes+" explores Jackson, Mississippi\'s failing infrastructure and severe water crisis',
#  'Opinion: Jackson water crisis shows Nina Simone is still right about Mississippi',
#  'Mississippi faces water crisis after brutal winter storm',
#  'Tens of Thousands of Jackson, Mississippi Residents Still Without Water',
#  'Mississippi has gone 2 weeks without safe drinking water since storm',
#  'donating bottled water to Jackson, Mississippi',
# ...

# %%
#@author: txiao

import datanews
import pandas as pd
import math
datanews.api_key = '0e1oixqnn4f0fhdl3zod701ok'

# A function to search and save to csv the original file, file removing rows with the same title, file removing rows with both the same 
# title and source:

def datanews_api_search(keyword):
    response = datanews.news (q=keyword,from_date=("2021-02-10"),country='US',language=['en'],size=100,page=0)
    articles = response['hits']
    df_datanews = pd.DataFrame(articles)
    num_of_pages = int(math.ceil(response['numResults']/100))
    if num_of_pages>1:
        for i in range(1,num_of_pages):
            extra_page_response = datanews.news (q=keyword,from_date=("2018-01-01"),country='US',language=['en'],size=100,page=i)
            extra_articles = extra_page_response['hits']
            df_datanews = df_datanews.append(extra_articles, ignore_index=True)                  
    else: pass
# store file in csv
    punc = '''!()-[]{};:'"\, <>./?@#$%^&*_~+'''
# Removing punctuations in string
# Using loop + punctuation string
    for ele in keyword: 
        if ele in punc: 
            keyword = keyword.replace(ele, "") 
# remove duplicated rows by title:
    no_dup = df_datanews.drop_duplicates(subset=('title'),ignore_index=True)
# remove duplicated rows by title & source match: 
    no_dup_2 = df_datanews.drop_duplicates(subset=('title','source'),ignore_index=True)
    #df_datanews.to_csv(keyword+".csv")
    #no_dup.to_csv(keyword+"_no_duplicated_title.csv")
   # no_dup_2.to_csv(keyword+"_no_duplicated_title_source.csv")
    return no_dup, no_dup_2

# Search five different keywords: 
keyword1 = '"water crisis" + Jackson Mississippi'
df1, df2=datanews_api_search(keyword1)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-6f4fa0554684> in <module>
#      38 # Search five different keywords:
#      39 keyword1 = '"water crisis" + Jackson Mississippi'
# ---> 40 df1, df2=datanews_api_search(keyword1)
#      41 df1
#
# <ipython-input-11-6f4fa0554684> in datanews_api_search(keyword)
#      17         for i in range(1,num_of_pages):
#      18             extra_page_response = datanews.news (q=keyword,from_date=("2018-01-01"),country='US',language=['en'],size=100,page=i)
# ---> 19             extra_articles = extra_page_response['hits']
#      20             df_datanews = df_datanews.append(extra_articles, ignore_index=True)
#      21     else: pass
#
# KeyError: 'hits'

# %%
#keyword- Nick Judin JWC
list=[]

googlenews=GoogleNews(start='02/10/2021',end='06/20/2021')
googlenews.search("Nick Judin Jackson water crisis")
result=googlenews.result()
df=pd.DataFrame(result)

for i in range(2,3):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent
config.request_timeout = 50


for ind in df.index:
    try:
        dict={}
        article = Article(df['link'][ind],config=config)
        article.download()
        article.parse()
        article.nlp()
        dict['Date']=df['date'][ind]
        dict['Media']=df['media'][ind]
        dict['Title']=article.title
        dict['Article']=article.text
        dict['Summary']=article.summary
        list.append(dict)
    except:
        print("caught a timeout")

googlenews.clear()


urls=["https://www.mississippifreepress.org/9824/lt-gov-hosemann-blames-jackson-leadership-since-last-white-mayor-for-water-crisis-mayor-harvey-johnson-jr-fires-back/",
     "https://www.mississippifreepress.org/10682/under-the-surface-part-2-after-jackson-freeze-the-fog-of-war/"]
for url in urls:
    try:
        dict={}
        print(url)
        article = Article(url,config=config)
        article.download()
        article.parse()
        article.nlp()
    
        dict['Date']=article.publish_date
        dict['Title']=article.title
        dict['Article']=article.text
        dict['Summary']=article.summary
        list.append(dict)
    except:
        print("caught a timeout")

news_df_NickJWC=pd.DataFrame(list)
news_df_NickJWC
# Out:
# 'NoneType' object is not iterable
# https://www.mississippifreepress.org/9824/lt-gov-hosemann-blames-jackson-leadership-since-last-white-mayor-for-water-crisis-mayor-harvey-johnson-jr-fires-back/
# https://www.mississippifreepress.org/10682/under-the-surface-part-2-after-jackson-freeze-the-fog-of-war/
#                         Date                   Media  \
# 0                Mar 3, 2021      Jackson Free Press
# 1               Mar 23, 2021                   Slate
# 2               Mar 23, 2021          Slate Magazine
# 3                Mar 6, 2021                NBC News
# 4               Mar 26, 2021                    WBUR
# 5                1 month ago  Mississippi Free Press
# 6               Mar 25, 2021  Mississippi Free Press
# 7                1 month ago  Mississippi Free Press
# 8  2021-03-02 01:54:57+00:00                     NaN
# 9  2021-03-27 02:34:08+00:00                     NaN
#
#                                                Title  \
# ...
